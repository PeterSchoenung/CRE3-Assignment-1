# %% [markdown]
# # This is a Test

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 1
b = 2
c = b+a+b


baba = "Test, ob mein Desktop PC verbunden werden kann." # Test, ob das alles hier geht

abab = "Test, ob es auch rückwärts mit dem Laptop geht." # Test, ob es auch rückwärts mit dem Laptop geht.

coolio = "Testen, ob die FUnktionalität nach dem Verschieben gegeben ist."
